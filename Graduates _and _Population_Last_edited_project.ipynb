# %% [markdown]
# # Data on a number of graduates and population in Uzbekistan (2010-2019)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
graduates= pd.read_csv('my_project_graduates_last_edited.csv')
pd.set_option('display.max_columns',None)
graduates
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
# 1  2011                    76379          29123400          _
# 2  2012                    86255          29555400          _
# 3  2013                    60925          29993500          _
# 4  2014                    60524          30492800          _
# 5  2015                    67643          31022500          _
# 6  2016                    66290          31575300          _
# 7  2017                    64133          32120500          _
# 8  2018                    67448          32656700          _
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
# 1             4974  1680900     4511  2672300     4417  1683800     2549
# ...

# %%
#Uzbekistan,Tashkent City

graduates= pd.read_csv('my_project_graduates_last_edited.csv')

fig = plt.figure(figsize=(11,4),facecolor='ivory')
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

fig.suptitle('Graduates in Uzbekistan during the decade'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")

plt.plot(graduates.Year, graduates.Graduates_in_Uzbekistan,'.--', color="red",
        label='Uzbekistan')
plt.plot(graduates.Year, graduates.TashkentCity, '.--', color="lime",
        label='Tashkent City')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()

print("_______________________________________________________________________________________________________")
print("Graduates compared to population in 2010 and 2019")
 
import matplotlib.pyplot as plt

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [71791, 28001400]
explode = (0.05, 0)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Uzbekistan',loc='upper right', bbox_to_anchor=(1,0,0.3,1))

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()

plt.title('                                                     in 2010 ', fontsize=14, fontweight='bold', color="darkblue")

plt.show()



labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [30259, 2234300]
explode = (0, 0)   

fig1, ax1 = plt.subplots(figsize=(4,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Tashkent City',loc='upper right', bbox_to_anchor=(1,0,0.3,1))

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()

plt.show()

print("_______________________________________________________________________________________________________")

# In Uzbekistan
import matplotlib.pyplot as plt
#plt.style.use('default')

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [66594, 33255500]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Uzbekistan', loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                                       2019', fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

 #plt.style.use('default')

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [23469, 2509900]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Tashkent City',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()

plt.show()
# Out:
# _______________________________________________________________________________________________________
# Graduates compared to population in 2010 and 2019
# _______________________________________________________________________________________________________

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900

# %%
fig = plt.figure(figsize=(11,4),facecolor='ivory')
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)


fig.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")

plt.plot(graduates.Year, graduates.Bukhara,'.-', color="orangered",
        label='Bukhara')
plt.plot(graduates.Year, graduates.Jizzakh ,'.-', color="indigo",
        label='Jizzakh')
plt.plot(graduates.Year, graduates.Kashkadarya,'.-', color="magenta",
        label='Kashkadarya')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
plt.show()


labels = 'Graduates', 'Population'

sizes = [3648, 1612500]
colors=['r', '#99ff99']

explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Bukhara',loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                                        in 2010', fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2108, 1116800]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Jizzakh',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2719, 1116800]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Kashkadarya ',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()


print("_______________________________________________________________________________________________________________________")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [3430, 1894800]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Bukhara',loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                                          in 2019', fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2855, 1352400]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Jizzakh',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [3774, 3213100]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Kashkadarya ',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _______________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900

# %%
graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4),facecolor='ivory')
plt.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="red")
plt.plot(graduates.Year, graduates.Samarkand,'.-', color="pink",
        label='Samarkand')
plt.plot(graduates.Year, graduates.Karakalpakistan,'y.-',
        label='Karakalpakistan')
 
plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper center',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [5329, 3119000]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Samarkand',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2010',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout() 
plt.show()


print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [4648, 1632000]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Karakalpakistan',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_______________________________________________________________________________________________________________________")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [6533, 3798900]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Samarkand",loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                In 2019',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()


print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [4424, 1869800]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Karakalpakistan",loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _______________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4),facecolor='ivory')


plt.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")
plt.plot(graduates.Year, graduates.Navoi,'.-', color="orange",
        label='Navoi')
plt.plot(graduates.Year, graduates.Namangan,'.-', color="turquoise",
        label='Namangan')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper center',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2332, 851600]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Navoi',loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                In 2010',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [3475, 2258500]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Namangan',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_______________________________________________________________________________________________________________________")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2268, 979500]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Navoi",loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                In 2019',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2964, 2752900]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Namangan",loc='upper right', bbox_to_anchor=(1,0,0.3,1))


#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _______________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900

# %%
#Surkhandarya, Syrdarya, 
plt.subplots(figsize=(11,4), facecolor='ivory')
plt.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")

plt.plot(graduates.Year, graduates.Surkhandarya,'.-', color='salmon',
        label='Surkhandarya')
plt.plot(graduates.Year, graduates.Syrdarya,'.-', color='sienna',
        label='Syrdarya')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
 
plt.show()

 

labels = 'Graduates', 'Population'

colors=['r', '#99ff99']
sizes = [1938, 2075000]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Surkhandarya",loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2010',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()

plt.show()
 
print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [915, 714400]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Syrdarya",loc='upper right', bbox_to_anchor=(1,0,0.3,1))
 #draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()


print("_____________________________________________________________________________________________________________________")


labels = 'Graduates', 'Population'
#colors=['brightgreen', 'red']
sizes = [1936, 2569900]
explode = (0.05, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Surkhandarya",loc='upper right', bbox_to_anchor=(1,0,0.3,1))

plt.title('                                In 2019',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

 
print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [1014, 829900]
explode = (0.05, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title="Syrdarya",loc='upper right', bbox_to_anchor=(1,0,0.3,1))
 #draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _____________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900

# %%
#Andijan,Fergana,Khorezm

graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4),facecolor='ivory')
plt.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")

plt.plot(graduates.Year, graduates.Andijan,'.-', color='navy',
        label='Andijan')
plt.plot(graduates.Year, graduates.Fergana,'.-', color='orchid',
        label='Fergana')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [3865, 2549100]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Andijan',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2010',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [5341, 3074600]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Fergana',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()



print("_________________________________________________________________________________________________________________________")




labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [4636, 3066900]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Andijan',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2019',fontsize=16, fontweight='bold', color="darkblue")
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")

labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [4499, 3683300]
explode = (0,0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Fergana',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _________________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900

# %%
 #Tashkent, Khorezm

graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4), facecolor='ivory')
plt.suptitle('Graduates'+" (2010-2019)", fontsize=14, fontweight='bold', color="darkblue")

plt.plot(graduates.Year, graduates.Tashkent,'.-', color='teal',
        label='Tashkent')
plt.plot(graduates.Year, graduates.Khorezm,'.-', color='red',
        label='Khorezm')

plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13}, color="indigo")           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2769, 2585900]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Tashkent',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2010',fontsize=16, fontweight='bold', color="darkblue")

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2445, 1561600]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Khorezm', loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()


print("_____________________________________________________________________________________________________________________")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2590, 2898500]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Tashkent',loc='upper right', bbox_to_anchor=(1,0,0.3,1))
plt.title('                                In 2019',fontsize=16, fontweight='bold', color="darkblue")

#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()

plt.show()

print("_-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_")


labels = 'Graduates', 'Population'
colors=['r', '#99ff99']
sizes = [2202, 1835700]
explode = (0, 0.05)   

fig1, ax1 = plt.subplots(figsize=(5,3))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',colors=colors,
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title='Khorezm', loc='upper right', bbox_to_anchor=(1,0,0.3,1))
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_
# _____________________________________________________________________________________________________________________
# _-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-__-_

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.head(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 0  2010                    71791          28001400          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 0             4648  1632000     3865  2549100     3648  1612500     2108
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 0  1116800         2719  2616100   2332  851600      3475  2258500       5329
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 0  3119000          1938  2075000       915  714400      2769  2585900
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 0     5341  3074600     2445  1561600         30259  2234300

# %%
df = pd.read_csv('my_project_graduates_last_edited.csv')

df.tail(1)
# Out:
#    Year  Graduates_in_Uzbekistan  Total_Population By_regions  \
# 9  2019                    66594          33255500          _
#
#    Karakalpakistan    Pop_1  Andijan    Pop_2  Bukhara    Pop_3  Jizzakh  \
# 9             4424  1869800     4636  3066900     3430  1894800     2855
#
#      Pop_4  Kashkadarya    Pop_5  Navoi   Pop_6  Namangan    Pop_7  Samarkand  \
# 9  1352400         3774  3213100   2268  979500      2964  2752900       6533
#
#      Pop_8  Surkhandarya    Pop_9  Syrdarya  Pop_10  Tashkent   Pop_11  \
# 9  3798900          1936  2569900      1014  829900      2590  2898500
#
#    Fergana   Pop_12  Khorezm   Pop_13  TashkentCity   Pop_14
# 9     4499  3683300     2202  1835700         23469  2509900
