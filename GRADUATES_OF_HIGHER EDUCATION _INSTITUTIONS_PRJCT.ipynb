# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
graduates= pd.read_csv('my_project_graduates.csv')
graduates
# Out:
#    Year  Uzbekistan  Karakalpakistan  Andijan  Bukhara  Jizzakh  Kashkadarya  \
# 0  2010       71791             4648     3865     3648     2108         2719
# 1  2011       76379             4974     4511     4417     2549         3639
# 2  2012       86255             4979     4661     4385     2416         3935
# 3  2013       60925             3704     2926     3026     1988         2445
# 4  2014       60524             3834     3427     3138     2157         2543
# 5  2015       67643             3752     3425     3484     2183         2834
# 6  2016       66290             3957     3664     3357     2469         2990
# 7  2017       64133             3939     4039     3376     2261         3111
# 8  2018       67448             4358     4209     3409     2732         3559
# 9  2019       66594             4424     4636     3430     2855         3774
#
#    Navoi  Namangan  Samarkand  Surkhandarya  Syrdarya  Tashkent  Fergana  \
# ...

# %%
graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4))

plt.title('Graduates during the decade between 2010 and 2019', fontdict={'fontweight':'bold', 'fontsize':15})
plt.plot(graduates.Year, graduates.Uzbekistan,'b.--',
        label='Uzbekistan')
plt.plot(graduates.Year, graduates.TashkentCity, 'r.--',
        label='Tashkent City')


plt.xticks(graduates.Year)
plt.ylabel('Number of students',fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13})           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')

plt.show()

graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4))



plt.plot(graduates.Year, graduates.Bukhara,'y.-',
        label='Bukhara')
plt.plot(graduates.Year, graduates.Jizzakh ,'r.-',
        label='Jizzakh')
plt.plot(graduates.Year, graduates.Kashkadarya,'b.-',
        label='Kashkadarya')

plt.xticks(graduates.Year)
plt.ylabel('A Number of the students',fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13})           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
plt.show()



graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4))

plt.plot(graduates.Year, graduates.Navoi,'g.-',
        label='Navoi')
plt.plot(graduates.Year, graduates.Namangan,'b.-',
        label='Namangan')
plt.plot(graduates.Year, graduates.Samarkand,'r.-',
        label='Samarkand')
plt.plot(graduates.Year, graduates.Karakalpakistan,'y.-',
        label='Karakalpakistan')
 
plt.xticks(graduates.Year)
plt.ylabel('A Number of the students',fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13})           
plt.legend(loc='upper center',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
plt.show()

graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4))

plt.plot(graduates.Year, graduates.Surkhandarya,'r.-',
        label='Surkhandarya')
plt.plot(graduates.Year, graduates.Syrdarya,'y.-',
        label='Syrdarya')
plt.plot(graduates.Year, graduates.Tashkent,'b.-',
        label='Tashkent')

plt.xticks(graduates.Year)
plt.ylabel('A Number of the students',fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13})           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
plt.show()

graduates= pd.read_csv('my_project_graduates.csv')
plt.subplots(figsize=(11,4))

plt.plot(graduates.Year, graduates.Andijan,'y.-',
        label='Andijan')
plt.plot(graduates.Year, graduates.Fergana,'g.-',
        label='Fergana')
plt.plot(graduates.Year, graduates.Khorezm,'r.-',
        label='Khorezm')


plt.xticks(graduates.Year)
plt.ylabel('A Number of the students',fontdict={'fontweight':'bold', 'fontsize':13})
plt.xlabel('Y e a r s',fontdict={'fontweight':'bold', 'fontsize':13})           
plt.legend(loc='upper right',fontsize=10, edgecolor="green", facecolor="white")
plt.grid(b=True, linestyle='dashdot')
plt.show()
